# %%
import pandas as pd

# Define the file path
file_path = "/OneDrive - University of Roehampton/Papers in progress/MSC Analysis.py/Egypt PreCov/your_file.csv"

# Load the data into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data was loaded correctly
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 file_path = "/OneDrive - University of Roehampton/Papers in progress/MSC Analysis.py/Egypt PreCov/your_file.csv"
#       6 # Load the data into a DataFrame
# ----> 7 df = pd.read_csv(file_path)
#       9 # Display the first few rows of the DataFrame to verify the data was loaded correctly
#      10 print(df.head())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/OneDrive - University of Roehampton/Papers in progress/MSC Analysis.py/Egypt PreCov/your_file.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the provided data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       4 # Create a DataFrame from the provided data
#       5 data = {
#       6     "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
#       7     "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
#    (...)
#      11     "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
#      12 }
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp312-cp312-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.6 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 2.8 MB/s eta 0:00:00
# Downloading pillow-10.3.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.9 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.3.0 pyparsing-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the provided data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

df = pd.DataFrame(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot the trends
plt.figure(figsize=(6, 4))
plt.plot(df['Year'], df['FDI'], marker='o', label='FDI')
plt.plot(df['Year'], df['UNEMPLOY'], marker='o', label='Unemployment')
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Trend Analysis: FDI and Unemployment')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Perform ADF test for each variable
for column in df.columns[1:]:
    result = adfuller(df[column])
    print(f"ADF Test for {column}:")
    print(f"ADF Statistic: {result[0]}")
    print(f"p-value: {result[1]}")
    print(f"Critical Values:")
    for key, value in result[4].items():
        print(f"   {key}: {value}")
    print("------------------------------------")
# Out:
# ADF Test for FDI:
# ADF Statistic: -2.900686827107231
# p-value: 0.04526818710091887
# Critical Values:
#    1%: -3.7112123008648155
#    5%: -2.981246804733728
#    10%: -2.6300945562130176
# ------------------------------------
# ADF Test for RGDP:
# ADF Statistic: -3.5084213556563926
# p-value: 0.007773431551766703
# Critical Values:
#    1%: -3.7238633119999998
#    5%: -2.98648896
#    10%: -2.6328004
# ------------------------------------
# ADF Test for UNEMPLOY:
# ADF Statistic: 0.4916147535282009
# p-value: 0.9846159927879202
# Critical Values:
#    1%: -3.7883858816542486
#    5%: -3.013097747543462
#    10%: -2.6463967573696143
# ------------------------------------
# ADF Test for INTEREST:
# ADF Statistic: -0.7933054262005492
# p-value: 0.8210806427097042
# Critical Values:
#    1%: -3.7238633119999998
#    5%: -2.98648896
#    10%: -2.6328004
# ------------------------------------
# ADF Test for INF:
# ADF Statistic: -1.7476142043904799
# p-value: 0.40676207223374716
# Critical Values:
#    1%: -3.6996079738860943
#    5%: -2.9764303469999494
#    10%: -2.627601001371742
# ------------------------------------

# %%
import pandas as pd

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate mean, median, variance, covariance, and autocovariance
for column in df.columns[1:]:
    print(f"Variable: {column}")
    print(f"Mean: {df[column].mean()}")
    print(f"Median: {df[column].median()}")
    print(f"Variance: {df[column].var()}")
    print(f"Covariance with FDI: {df[column].cov(df['FDI'])}")
    print(f"Autocovariance: {df[column].autocov(1)}")
    print("-----------------------------")
# Out:
# Variable: FDI
# Mean: 2.3721428571428573
# Median: 1.3599999999999999
# Variance: 5.774891534391537
# Covariance with FDI: 5.774891534391537
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w7/90xs8_t97d3d89dywgvlnd0r0000gn/T/ipykernel_24880/1563036394.py in ?()
#      19     print(f"Mean: {df[column].mean()}")
#      20     print(f"Median: {df[column].median()}")
#      21     print(f"Variance: {df[column].var()}")
#      22     print(f"Covariance with FDI: {df[column].cov(df['FDI'])}")
# ---> 23     print(f"Autocovariance: {df[column].autocov(1)}")
#      24     print("-----------------------------")
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'autocov'

# %%
import pandas as pd
import numpy as np

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate mean, median, variance, covariance, and autocovariance
for column in df.columns[1:]:
    print(f"Variable: {column}")
    print(f"Mean: {df[column].mean()}")
    print(f"Median: {df[column].median()}")
    print(f"Variance: {df[column].var()}")
    print(f"Covariance with FDI: {df[column].cov(df['FDI'])}")
    print(f"Autocovariance: {np.cov(df[column], df[column].shift())[0, 1]}")
    print("-----------------------------")
# Out:
# Variable: FDI
# Mean: 2.3721428571428573
# Median: 1.3599999999999999
# Variance: 5.774891534391537
# Covariance with FDI: 5.774891534391537
# Autocovariance: nan
# -----------------------------
# Variable: RGDP
# Mean: 4.338928571428572
# Median: 4.42
# Variance: 2.5940099206349205
# Covariance with FDI: 2.433946825396825
# Autocovariance: nan
# -----------------------------
# Variable: UNEMPLOY
# Mean: 10.396607142857144
# Median: 10.4525
# Variance: 2.645379062169312
# Covariance with FDI: 0.04080124338624365
# Autocovariance: nan
# -----------------------------
# Variable: INTEREST
# Mean: 3.9257142857142857
# Median: 3.425
# Variance: 22.58036613756614
# Covariance with FDI: -2.52963492063492
# Autocovariance: nan
# -----------------------------
# Variable: INF
# Mean: 9.726892857142857
# Median: 9.2035
# Variance: 31.28140380291005
# Covariance with FDI: 1.711635052910053
# Autocovariance: nan
# -----------------------------

# %%
import pandas as pd
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Perform Johansen cointegration test
coint_result = coint_johansen(df[['FDI', 'UNEMPLOY']], det_order=0, k_ar_diff=1)

# Print the results
print("Johansen Cointegration Test Results:")
print("Eigenvalues:")
print(coint_result.lr1)
print("\nCritical values (90%, 95%, 99%):")
print(coint_result.cvt)
print("\nTrace statistic:")
print(coint_result.lr2)
# Out:
# Johansen Cointegration Test Results:
# Eigenvalues:
# [12.73937345  5.23539696]
#
# Critical values (90%, 95%, 99%):
# [[13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]
#
# Trace statistic:
# [7.50397649 5.23539696]

# %%
import pandas as pd
import statsmodels.api as sm

# Define the data
data = {
    "Year": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Define the dependent and independent variables
X = df["FDI"]  # independent variable
y = df["UNEMPLOY"]  # dependent variable

# Add constant to the independent variable
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               UNEMPLOY   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                  0.002834
# Date:                Thu, 16 May 2024   Prob (F-statistic):              0.958
# Time:                        01:59:42   Log-Likelihood:                -52.839
# No. Observations:                  28   AIC:                             109.7
# Df Residuals:                      26   BIC:                             112.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.3798      0.444     23.372      0.000       9.467      11.293
# FDI            0.0071      0.133      0.053      0.958      -0.266       0.280
# ==============================================================================
# Omnibus:                        3.210   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.201   Jarque-Bera (JB):                1.553
# Skew:                           0.218   Prob(JB):                        0.460
# Kurtosis:                       1.932   Cond. No.                         4.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import statsmodels.api as sm

# Define the data
data = {
    "YEAR": [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
    "FDI": [0.68, 1.1, 1.06, 2.42, 0.99, 0.94, 1.14, 1.27, 1.17, 1.24, 0.53, 0.76, 0.3, 1.59, 6, 9.35, 8.88, 5.83, 3.55, 2.92, -0.2, 1, 1.45, 1.51, 2.1, 2.44, 3.14, 3.26],
    "RGDP": [1.13, 4.47, 2.9, 3.97, 4.64, 4.99, 5.49, 5.58, 6.05, 6.37, 3.54, 2.39, 3.19, 4.09, 4.47, 6.84, 7.09, 7.16, 4.67, 5.15, 1.76, 2.23, 2.19, 2.92, 4.37, 4.35, 4.18, 5.31],
    "UNEMPLOY": [8.791, 8.952, 10.911, 11.143, 11.176, 9.467, 8.671, 7.955, 7.692, 8.995, 8.808, 10.05, 11.275, 10.526, 11.468, 10.917, 9.205, 8.676, 9.367, 9.21, 10.379, 12.373, 12.992, 13.365, 12.859, 12.705, 12.245, 10.932],
    "INTEREST": [3.2, 1.67, 9.1, 7.44, 4.55, 7.91, 3.56, 10.39, 11.94, 8.92, 11.21, 10.3, 6.33, 1.53, 6.52, 4.88, -0.08, 0.11, 0.71, 0.82, -0.56, -6.26, 3.29, 0.41, 1.54, 6.92, -3.87, -2.56],
    "INF": [14.737, 21.142, 11.042, 9.046, 9.361, 7.095, 6.167, 5.041, 3.745, 2.849, 2.425, 2.431, 3.21, 8.106, 8.826, 4.202, 10.959, 11.698, 16.24, 11.69, 11.09, 8.65, 6.914, 10.097, 10.994, 10.199, 23.537, 20.86]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Define dependent and independent variables
y = df["UNEMPLOY"]
X = df[["FDI", "RGDP", "INTEREST", "INF"]]

# Add constant to the independent variables
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               UNEMPLOY   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     3.190
# Date:                Thu, 16 May 2024   Prob (F-statistic):             0.0319
# Time:                        02:52:04   Log-Likelihood:                -46.661
# No. Observations:                  28   AIC:                             103.3
# Df Residuals:                      23   BIC:                             110.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.3445      1.163     11.475      0.000      10.939      15.750
# FDI            0.2279      0.156      1.459      0.158      -0.095       0.551
# RGDP          -0.6131      0.228     -2.687      0.013      -1.085      -0.141
# INTEREST      -0.1127      0.081     -1.386      0.179      -0.281       0.056
# INF           -0.0397      0.066     -0.604      0.552      -0.176       0.096
# ==============================================================================
# Omnibus:                        0.053   Durbin-Watson:                   0.586
# Prob(Omnibus):                  0.974   Jarque-Bera (JB):                0.075
# Skew:                           0.050   Prob(JB):                        0.963
# Kurtosis:                       2.766   Cond. No.                         54.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
